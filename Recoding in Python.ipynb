# %% [markdown]
# # Part 1: Recoding in Python

# %%
import pandas as pd

# %%
EatingHabits = pd.read_csv('C:/Users/keitr/Downloads/Eating_Habits/Eating_Habits.csv')

# %%
EatingHabits.head()
# Out:
#    REF_DATE      GEO  DGUID    Sex Age group      Activity  \
# 0      1990  Austria    NaN  Males  11 years  Eating fruit
# 1      1990  Austria    NaN  Males  11 years  Eating fruit
# 2      1990  Austria    NaN  Males  11 years  Eating fruit
# 3      1990  Austria    NaN  Males  11 years  Eating fruit
# 4      1990  Austria    NaN  Males  11 years  Eating fruit
#
#               Frequency      UOM  UOM_ID SCALAR_FACTOR  SCALAR_ID   VECTOR  \
# 0  More than once a day  Percent     239        units           0  v656366
# 1            Once a day  Percent     239        units           0  v656367
# 2  At least once a week  Percent     239        units           0  v656368
# 3                Seldom  Percent     239        units           0  v656369
# 4                 Never  Percent     239        units           0  v656370
#
#   COORDINATE  VALUE  STATUS  SYMBOL TERMINATED  DECIMALS
# 0  1.1.1.1.1     34     NaN     NaN        NaN         0
# ...

# %% [markdown]
# # Recode Activity into a New Variable

# %%
EatingHabits.Activity.value_counts()
# Out:
# Eating fruit                                             1890
# Eating candy, chocolate bars                             1890
# Eating french fries                                      1890
# Eating hamburgers, hot dogs or sausages                  1890
# Eating whole wheat or rye bread                          1890
# Drinking soft drinks, cola or other drinks with sugar    1890
# Drinking coffee                                          1890
# Eating raw vegetables                                    1800
# Eating potato chips, crisps                              1710
# Drinking low fat milk                                    1440
# Drinking whole milk                                      1440
# Eating peanuts                                            780
# Name: Activity, dtype: int64

# %%
def activity (series):
    if series == "Eating fruit":
        return 0
    if series == "Drinking soft drinks, cola, or other drinks with sugar":
        return 0
    if series == "Drinking coffee":
        return 0
    if series == "Eating french frie3s":
        return 0
    if series == "Eating hamburger, hotdogs, or sausages":
        return 0
    if series == "Eating candy, chocolate bars":
        return 1
    if series == "Eating whole meat or rye bread":
        return 0
    if series == "Eating ray vegetables":
        return 0
    if series == "Eating potato chipsm crisps":
        return 0
    if series == "Drinking whole milk":
        return 0
    if series == "Drinking low fat milk":
        return 0
    if series == "Eating peanuts":
        return 0

# %%
EatingHabits['ChocolateYN'] = EatingHabits['Activity'].apply(activity)

# %%
EatingHabits.head()
# Out:
#    REF_DATE      GEO  DGUID    Sex Age group      Activity  \
# 0      1990  Austria    NaN  Males  11 years  Eating fruit
# 1      1990  Austria    NaN  Males  11 years  Eating fruit
# 2      1990  Austria    NaN  Males  11 years  Eating fruit
# 3      1990  Austria    NaN  Males  11 years  Eating fruit
# 4      1990  Austria    NaN  Males  11 years  Eating fruit
#
#               Frequency      UOM  UOM_ID SCALAR_FACTOR  SCALAR_ID   VECTOR  \
# 0  More than once a day  Percent     239        units           0  v656366
# 1            Once a day  Percent     239        units           0  v656367
# 2  At least once a week  Percent     239        units           0  v656368
# 3                Seldom  Percent     239        units           0  v656369
# 4                 Never  Percent     239        units           0  v656370
#
#   COORDINATE  VALUE  STATUS  SYMBOL TERMINATED  DECIMALS  ChocolateYN
# 0  1.1.1.1.1     34     NaN     NaN        NaN         0          0.0
# ...

# %% [markdown]
# # Recode Frequency and Sex from text to numbers in the same variable

# %%
EatingHabits.Frequency.value_counts()
# Out:
# More than once a day    4080
# Once a day              4080
# At least once a week    4080
# Seldom                  4080
# Never                   4080
# Name: Frequency, dtype: int64

# %%
EatingHabits.Sex.value_counts()
# Out:
# Males      10200
# Females    10200
# Name: Sex, dtype: int64

# %%
cleanup = {"Frequency" : {"Never": 0, "Seldom":1, "At least once a week": 2, "Once a day": 3, "More than once a day": 4},"Sex":{"Females": 0, "Males":1}}

# %%
EatingHabits.replace(cleanup, inplace=True)

# %%
EatingHabits.head()
# Out:
#    REF_DATE      GEO  DGUID  Sex Age group      Activity  Frequency      UOM  \
# 0      1990  Austria    NaN    1  11 years  Eating fruit          4  Percent
# 1      1990  Austria    NaN    1  11 years  Eating fruit          3  Percent
# 2      1990  Austria    NaN    1  11 years  Eating fruit          2  Percent
# 3      1990  Austria    NaN    1  11 years  Eating fruit          1  Percent
# 4      1990  Austria    NaN    1  11 years  Eating fruit          0  Percent
#
#    UOM_ID SCALAR_FACTOR  SCALAR_ID   VECTOR COORDINATE  VALUE  STATUS  SYMBOL  \
# 0     239        units           0  v656366  1.1.1.1.1     34     NaN     NaN
# 1     239        units           0  v656367  1.1.1.1.2     42     NaN     NaN
# 2     239        units           0  v656368  1.1.1.1.3     17     NaN     NaN
# 3     239        units           0  v656369  1.1.1.1.4      4     NaN     NaN
# 4     239        units           0  v656370  1.1.1.1.5      3     NaN     NaN
#
# ...
